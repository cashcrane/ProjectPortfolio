# %% [markdown]
# # Sample Data showing output of fetch_data.ipynb.
# **Notes:**
# The last column 'rn' is used to track the number of records for a specific trade responsibility in order to limit random sampling to 9,500 records per class.

# %%
import pandas as pd
from IPython.display import display

# Create a sample DataFrame with 6 rows
data = {
    "ProjectObjectID": [101, 102, 103, 104, 105, 106],
    "ActivityObjectID": [1001, 1002, 1003, 1004, 1005, 1006],
    "ActivityCode": ["CON", "ELEC", "PAINT", "ARCH", "GC", "CON"],
    "ActivityName": [
        "Pour Concrete Foundation",
        "Install Electrical Conduit",
        "Apply Paint to Walls",
        "Review Architectural Plans",
        "General Contractor Supervision",
        "Lay Concrete Driveway"
    ],
    "WbsobjectID": [201, 202, 203, 204, 205, 206],
    "Name": ["Foundation", "Level 2", "Interior Finishes", "Design", "Management", "Sitework"],
    "MergedActivityCodeValue": ["CON", "ELEC", "PAINT", "ARCH", "GC", "CON"],
    "ActivityCodeDescription": [
        "Concrete",
        "Electrical",
        "Paint",
        "Architectural Review",
        "General Contractor",
        "Concrete"
    ],
    "ActivityCodeTypeName": [
        "Trade Responsibility",
        "Trade Responsibility",
        "Trade Responsibility",
        "Trade Responsibility",
        "Trade Responsibility",
        "Trade Responsibility"
    ],
    "ActivityCodeTypeScope": [
        "Construction",
        "Construction",
        "Construction",
        "Design",
        "Management",
        "Construction"
    ],
    "UpdateDate": [
        "2024-03-10", "2022-01-12", "2023-07-24", "2024-02-13", "2018-06-05", "2024-03-11"
    ],
    "IngestedDateTime": [
        "2025-01-15 08:05:00", "2025-01-15 08:05:00", "2025-01-15 08:05:00",
        "2025-01-15 08:05:00", "2025-01-15 08:05:00", "2025-01-15 08:10:00"
    ],
    "rn": [1, 1, 1, 1, 1, 2]
}

# Convert the dictionary to a DataFrame
sample_df = pd.DataFrame(data)

# Display the DataFrame nicely
display(sample_df)
# Out:
#    ProjectObjectID  ActivityObjectID ActivityCode  \
# 0              101              1001          CON
# 1              102              1002         ELEC
# 2              103              1003        PAINT
# 3              104              1004         ARCH
# 4              105              1005           GC
# 5              106              1006          CON
#
#                      ActivityName  WbsobjectID               Name  \
# 0        Pour Concrete Foundation          201         Foundation
# 1      Install Electrical Conduit          202            Level 2
# 2            Apply Paint to Walls          203  Interior Finishes
# 3      Review Architectural Plans          204             Design
# 4  General Contractor Supervision          205         Management
# 5           Lay Concrete Driveway          206           Sitework
#
#   MergedActivityCodeValue ActivityCodeDescription  ActivityCodeTypeName  \
# ...
